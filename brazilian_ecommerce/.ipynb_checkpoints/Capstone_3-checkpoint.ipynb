# %%
#Building a regression model that tries to predict the estimated cumulative 6 month revenue from a new customer
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.formula.api as smf
import datetime as dt
# %matplotlib inline
import seaborn as sns
import lifetimes

# %%
item = pd.read_csv('olist_order_items_dataset.csv')
customer = pd.read_csv('olist_customers_dataset.csv')
payment = pd.read_csv('olist_order_payments_dataset.csv')
review = pd.read_csv('olist_order_reviews_dataset.csv')	
order = pd.read_csv('olist_orders_dataset.csv')
product = pd.read_csv('olist_products_dataset.csv')
sellers = pd.read_csv('olist_sellers_dataset.csv')

# %%
#order_id, order_item_id, product_id, seller_id, shipping_limit_date, price, freight_value
cols = ['order_id','product_id', 'seller_id', 'price', 'freight_value']
item = item[cols]
item = item.set_index('order_id')
item
# Out:
#                                                         product_id  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                                            ...
# fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
#                                                          seller_id   price  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214  48436dade18ac8b2bce089ec2a041202   58.90
# 00018f77f2f0320c557190d7a144bdd3  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 000229ec398224ef6ca0657da4fc703e  5b51032eddd242adc84c38acab88f23d  199.00
# 00024acbcdf0a6daa1e931b038114c75  9d7a1d34a5052409006425275ba1c2b4   12.99
# 00042b26cf59d7ce69dfabb4e55b4fd9  df560393f3a51e74553ab94004ba5c87  199.90
# ...                                                            ...     ...
# fffc94f6ce00a00581880bf54a75a037  b8bc237ba3788b23da09c0f1f3a3288c  299.99
# fffcd46ef2263f404302a634eb57f7eb  f3c38ab652836d21de61fb8314b69182  350.00
# fffce4705a9662cd70adb13d4a31832d  c3cfdc648177fdbbbb35635a37472c53   99.90
# fffe18544ffabc95dfada21779c9644f  2b3e4a2a3ea8e01938cabda2a3e5cc79   55.99
# fffe41c64501cc87c801fd61db3f6244  f7ccf836d21b2fb1de37564105216cc1   43.00
#
#                                   freight_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214          13.29
# 00018f77f2f0320c557190d7a144bdd3          19.93
# 000229ec398224ef6ca0657da4fc703e          17.87
# 00024acbcdf0a6daa1e931b038114c75          12.79
# 00042b26cf59d7ce69dfabb4e55b4fd9          18.14
# ...                                         ...
# fffc94f6ce00a00581880bf54a75a037          43.41
# fffcd46ef2263f404302a634eb57f7eb          36.53
# fffce4705a9662cd70adb13d4a31832d          16.95
# fffe18544ffabc95dfada21779c9644f           8.72
# fffe41c64501cc87c801fd61db3f6244          12.79
#
# [112650 rows x 4 columns]

# %%
item.shape
# Out:
# (112650, 4)

# %%
item[('seller_id')].describe()
# Out:
# count                               112650
# unique                                3095
# top       6560211a19b47992c3666cc44a7e94c0
# freq                                  2033
# Name: seller_id, dtype: object

# %%
payment=payment1.reset_index()

# %%
item[('product_id')].describe()
# Out:
# count                               112650
# unique                               32951
# top       aca2eb7d00ea1a7b8ebd4e68314663af
# freq                                   527
# Name: product_id, dtype: object

# %%
cols =['order_id', 'payment_sequential', 'payment_type', 'payment_installments', 'payment_value']
payment = payment[cols]

payment
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# 0                          8          99.33
# 1                          1          24.39
# 2                          1          65.71
# 3                          8         107.78
# 4                          2         128.45
# ...                      ...            ...
# 103881                     1         363.31
# 103882                     2          96.80
# 103883                     1          47.77
# 103884                     5         369.54
# 103885                     1         191.58
#
# [103886 rows x 5 columns]

# %%
payment1.shape
# Out:
# (103886, 4)

# %%
payment= payment.groupby('order_id').sum()
payment
# Out:
#                                   payment_sequential  payment_installments  \
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214                   1                     2
# 00018f77f2f0320c557190d7a144bdd3                   1                     3
# 000229ec398224ef6ca0657da4fc703e                   1                     5
# 00024acbcdf0a6daa1e931b038114c75                   1                     2
# 00042b26cf59d7ce69dfabb4e55b4fd9                   1                     3
# ...                                              ...                   ...
# fffc94f6ce00a00581880bf54a75a037                   1                     1
# fffcd46ef2263f404302a634eb57f7eb                   1                     1
# fffce4705a9662cd70adb13d4a31832d                   1                     3
# fffe18544ffabc95dfada21779c9644f                   1                     3
# fffe41c64501cc87c801fd61db3f6244                   1                     1
#
#                                   payment_value
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214          72.19
# 00018f77f2f0320c557190d7a144bdd3         259.83
# 000229ec398224ef6ca0657da4fc703e         216.87
# 00024acbcdf0a6daa1e931b038114c75          25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9         218.04
# ...                                         ...
# fffc94f6ce00a00581880bf54a75a037         343.40
# fffcd46ef2263f404302a634eb57f7eb         386.53
# fffce4705a9662cd70adb13d4a31832d         116.85
# fffe18544ffabc95dfada21779c9644f          64.71
# fffe41c64501cc87c801fd61db3f6244          55.79
#
# [99440 rows x 3 columns]

# %%
customer = pd.read_csv('olist_customers_dataset.csv')
cols = ['customer_id','customer_unique_id', 'customer_zip_code_prefix', 'customer_city', 'customer_state']
customer = customer.set_index('customer_id')
customer.head()
# Out:
#                                                 customer_unique_id  \
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#                                   customer_zip_code_prefix  \
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 18955e83d337fd6b2def6b18a428ac77                      9790
# 4e7b3e00288586ebd08712fdd0374a03                      1151
# b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4f2d8ab171c80ec8364f7c12e35b23ad                     13056
#
#                                           customer_city customer_state
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7                 franca             SP
# 18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo             SP
# 4e7b3e00288586ebd08712fdd0374a03              sao paulo             SP
# b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes             SP
# 4f2d8ab171c80ec8364f7c12e35b23ad               campinas             SP

# %%
customer.shape
# Out:
# (99441, 4)

# %%
customer['customer_state'].value_counts()
# Out:
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: customer_state, dtype: int64

# %%
#order table 
cols = ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
order = order[cols]
order = order.set_index('order_id')
order.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-127-ef987455abbd> in <module>
#       1 #order table
#       2 cols = ['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp', 'order_approved_at', 'order_delivered_carrier_date', 'order_delivered_customer_date', 'order_estimated_delivery_date']
# ----> 3 order = order[cols]
#       4 order = order.set_index('order_id')
#       5 order.head()
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2984             if is_iterator(key):
#    2985                 key = list(key)
# -> 2986             indexer = self.loc._convert_to_indexer(key, axis=1, raise_missing=True)
#    2987
#    2988         # take() does not accept boolean indexers
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1283                 # When setting, missing keys are not allowed, even with .loc:
#    1284                 kwargs = {"raise_missing": True if is_setter else raise_missing}
# -> 1285                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
#    1286         else:
#    1287             try:
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1090
#    1091         self._validate_read_indexer(
# -> 1092             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1093         )
#    1094         return keyarr, indexer
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1183             if not (self.name == "loc" and not raise_missing):
#    1184                 not_found = list(set(key) - set(ax))
# -> 1185                 raise KeyError("{} not in index".format(not_found))
#    1186
#    1187             # we skip the warning on Categorical/Interval
#
# KeyError: "['order_id'] not in index"

# %%
order.shape
# Out:
# (99441, 7)

# %%
cols = ['order_id','review_score', 'review_creation_date', 'review_answer_timestamp']
review1 = review[cols]
review1 = review.set_index('order_id')
review1
# Out:
#                                                          review_id  \
# order_id
# 73fc7af87114b39712e6da79b0a377eb  7bc2406110b926393aa56f80a40eba40
# a548910a1c6147796b98fdf73dbeba33  80e641a11e56f04c1ad469d5645fdfde
# f9e4b658b201a9f2ecdecbb34bed034b  228ce5500dc1d8e020d8d1322874b6f0
# 658677c97b385a9be170737859d3511b  e64fb393e7b32834bb789ff8bb30750e
# 8e6bfb81e283fa7e4f11123a3fb894f1  f7c4243c7fe1938f181bec41a392bdeb
# ...                                                            ...
# 22ec9f0669f784db00fa86d035cf8602  f3897127253a9592a73be9bdfdf4ed7a
# 55d4004744368f5571d1f590031933e4  b3de70c89b1510c4cd3d0649fd302472
# 7725825d039fc1f0ceb7635e3f7d9206  1adeb9d84d72fe4e337617733eb85149
# f8bd3f2000c28c5342fedeb5e50f2e75  be360f18f5df1e0541061c87021e6d93
# 90531360ecb1eec2a1fbb265a0db0508  efe49f1d6f951dd88b51e6ccd4cc548f
#
#                                   review_score review_comment_title  \
# order_id
# 73fc7af87114b39712e6da79b0a377eb             4                  NaN
# a548910a1c6147796b98fdf73dbeba33             5                  NaN
# f9e4b658b201a9f2ecdecbb34bed034b             5                  NaN
# 658677c97b385a9be170737859d3511b             5                  NaN
# 8e6bfb81e283fa7e4f11123a3fb894f1             5                  NaN
# ...                                        ...                  ...
# 22ec9f0669f784db00fa86d035cf8602             5                  NaN
# 55d4004744368f5571d1f590031933e4             5                  NaN
# 7725825d039fc1f0ceb7635e3f7d9206             4                  NaN
# f8bd3f2000c28c5342fedeb5e50f2e75             1                  NaN
# 90531360ecb1eec2a1fbb265a0db0508             1                  NaN
#
#                                                              review_comment_message  \
# order_id
# 73fc7af87114b39712e6da79b0a377eb                                                NaN
# a548910a1c6147796b98fdf73dbeba33                                                NaN
# f9e4b658b201a9f2ecdecbb34bed034b                                                NaN
# 658677c97b385a9be170737859d3511b              Recebi bem antes do prazo estipulado.
# 8e6bfb81e283fa7e4f11123a3fb894f1  Parabéns lojas lannister adorei comprar pela I...
# ...                                                                             ...
# 22ec9f0669f784db00fa86d035cf8602                                                NaN
# 55d4004744368f5571d1f590031933e4  Excelente mochila, entrega super rápida. Super...
# 7725825d039fc1f0ceb7635e3f7d9206                                                NaN
# f8bd3f2000c28c5342fedeb5e50f2e75  Solicitei a compra de uma capa de retrovisor c...
# 90531360ecb1eec2a1fbb265a0db0508  meu produto chegou e ja tenho que devolver, po...
#
#                                  review_creation_date review_answer_timestamp
# order_id
# 73fc7af87114b39712e6da79b0a377eb  2018-01-18 00:00:00     2018-01-18 21:46:59
# a548910a1c6147796b98fdf73dbeba33  2018-03-10 00:00:00     2018-03-11 03:05:13
# f9e4b658b201a9f2ecdecbb34bed034b  2018-02-17 00:00:00     2018-02-18 14:36:24
# 658677c97b385a9be170737859d3511b  2017-04-21 00:00:00     2017-04-21 22:02:06
# 8e6bfb81e283fa7e4f11123a3fb894f1  2018-03-01 00:00:00     2018-03-02 10:26:53
# ...                                               ...                     ...
# 22ec9f0669f784db00fa86d035cf8602  2017-12-09 00:00:00     2017-12-11 20:06:42
# 55d4004744368f5571d1f590031933e4  2018-03-22 00:00:00     2018-03-23 09:10:43
# 7725825d039fc1f0ceb7635e3f7d9206  2018-07-01 00:00:00     2018-07-02 12:59:13
# f8bd3f2000c28c5342fedeb5e50f2e75  2017-12-15 00:00:00     2017-12-16 01:29:43
# 90531360ecb1eec2a1fbb265a0db0508  2017-07-03 00:00:00     2017-07-03 21:01:49
#
# [100000 rows x 6 columns]

# %%
review = review.sort_values(by='order_id', ascending=False, na_position='first')
review= review.groupby('order_id').mean()
review
# Out:
#                                   review_score
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214           5.0
# 00018f77f2f0320c557190d7a144bdd3           4.0
# 000229ec398224ef6ca0657da4fc703e           5.0
# 00024acbcdf0a6daa1e931b038114c75           4.0
# 00042b26cf59d7ce69dfabb4e55b4fd9           5.0
# ...                                        ...
# fffc94f6ce00a00581880bf54a75a037           5.0
# fffcd46ef2263f404302a634eb57f7eb           5.0
# fffce4705a9662cd70adb13d4a31832d           5.0
# fffe18544ffabc95dfada21779c9644f           5.0
# fffe41c64501cc87c801fd61db3f6244           5.0
#
# [99441 rows x 1 columns]

# %%
#Joining tables
result = pd.merge(item, payment,how='left', on= 'order_id').reset_index()
result = result.sort_values(by='order_id')
result=result.drop_duplicates(subset=None, keep= 'first', inplace=False)
result.shape
# Out:
# (102425, 8)

# %%
result.head()
# Out:
#                            order_id                        product_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1  00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2  000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3  00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4  00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
#
#                           seller_id   price  freight_value  \
# 0  48436dade18ac8b2bce089ec2a041202   58.90          13.29
# 1  dd7ddc04e1b6c2c614352b383efe2d36  239.90          19.93
# 2  5b51032eddd242adc84c38acab88f23d  199.00          17.87
# 3  9d7a1d34a5052409006425275ba1c2b4   12.99          12.79
# 4  df560393f3a51e74553ab94004ba5c87  199.90          18.14
#
#    payment_sequential  payment_installments  payment_value
# 0                 1.0                   2.0          72.19
# 1                 1.0                   3.0         259.83
# 2                 1.0                   5.0         216.87
# 3                 1.0                   2.0          25.78
# 4                 1.0                   3.0         218.04

# %%
#Joining tables
#item, payment, product, order, customer, review
result = pd.merge(result, product,how='inner', on= 'product_id').sort_values(by='order_id')

# %%
result.shape
# Out:
# (102425, 16)

# %%
result = pd.merge(result, order,how='inner', on= 'order_id')
result = result.sort_values(by='order_id')
result = result.loc[:,~result.columns.duplicated()]
#result.columns

# %%
result1= result.loc[:,~result.columns.duplicated()]
result1.set_index('customer_id')
# Out:
#                                                           order_id  \
# customer_id
# 3ce436f183e68e07877b285a838db11a
# b5e6afd5a41800fdf401e0272ca74655           8.72                 1.0
# 96d649da0cc4ff33bb408b199d4c7dcf          12.79                 1.0
#
#                                   payment_installments  payment_value  \
# customer_id
# 3ce436f183e68e07877b285a838db11a                   2.0          72.19
# f6dd3ec061db4e3987629fe6b26e5cce                   3.0         259.83
# 6489ae5e4333f3693df5ad4372dab6d3                   5.0         216.87
# d4eb9395c8c0431ee92fce09860c5a06                   2.0          25.78
# 58dbd0b2d70206bf40e62cd34e84d795                   3.0         218.04
# ...                                                ...            ...
# b51593916b4b8e0d6f66f2ae24f2673d                   1.0         343.40
# 84c5d4fbaf120aae381fad077416eaa0                   1.0         386.53
# 29309aa813182aaddc9b259e31b870e6                   3.0         116.85
# b5e6afd5a41800fdf401e0272ca74655                   3.0          64.71
# 96d649da0cc4ff33bb408b199d4c7dcf                   1.0          55.79
#
#                                    product_category_name  product_name_lenght  \
# customer_id
# 3ce436f183e68e07877b285a838db11a              cool_stuff                 58.0
# f6dd3ec061db4e3987629fe6b26e5cce                pet_shop                 56.0
# 6489ae5e4333f3693df5ad4372dab6d3        moveis_decoracao                 59.0
# d4eb9395c8c0431ee92fce09860c5a06              perfumaria                 42.0
# 58dbd0b2d70206bf40e62cd34e84d795      ferramentas_jardim                 59.0
# ...                                                  ...                  ...
# b51593916b4b8e0d6f66f2ae24f2673d   utilidades_domesticas                 43.0
# 84c5d4fbaf120aae381fad077416eaa0  informatica_acessorios                 31.0
# 29309aa813182aaddc9b259e31b870e6           esporte_lazer                 43.0
# b5e6afd5a41800fdf401e0272ca74655  informatica_acessorios                 56.0
# 96d649da0cc4ff33bb408b199d4c7dcf         cama_mesa_banho                 47.0
#
#                                   ...  product_weight_g  product_length_cm  \
# customer_id                       ...
# 3ce436f183e68e07877b285a838db11a  ...             650.0               28.0
# f6dd3ec061db4e3987629fe6b26e5cce  ...           30000.0               50.0
# 6489ae5e4333f3693df5ad4372dab6d3  ...            3050.0               33.0
# d4eb9395c8c0431ee92fce09860c5a06  ...             200.0               16.0
# 58dbd0b2d70206bf40e62cd34e84d795  ...            3750.0               35.0
# ...                               ...               ...                ...
# b51593916b4b8e0d6f66f2ae24f2673d  ...           10150.0               89.0
# 84c5d4fbaf120aae381fad077416eaa0  ...            8950.0               45.0
# 29309aa813182aaddc9b259e31b870e6  ...             967.0               21.0
# b5e6afd5a41800fdf401e0272ca74655  ...             100.0               20.0
# 96d649da0cc4ff33bb408b199d4c7dcf  ...             600.0               30.0
#
#                                   product_height_cm  product_width_cm  \
# customer_id
# 3ce436f183e68e07877b285a838db11a                9.0              14.0
# f6dd3ec061db4e3987629fe6b26e5cce               30.0              40.0
# 6489ae5e4333f3693df5ad4372dab6d3               13.0              33.0
# d4eb9395c8c0431ee92fce09860c5a06               10.0              15.0
# 58dbd0b2d70206bf40e62cd34e84d795               40.0              30.0
# ...                                             ...               ...
# b51593916b4b8e0d6f66f2ae24f2673d               15.0              40.0
# 84c5d4fbaf120aae381fad077416eaa0               26.0              38.0
# 29309aa813182aaddc9b259e31b870e6               24.0              19.0
# b5e6afd5a41800fdf401e0272ca74655               20.0              20.0
# 29309aa813182aaddc9b259e31b870e6           2017-10-28 12:22:22
# b5e6afd5a41800fdf401e0272ca74655           2017-08-16 21:59:40
# 96d649da0cc4ff33bb408b199d4c7dcf           2018-06-14 17:56:26
#
#                                  order_estimated_delivery_date
# customer_id
# 3ce436f183e68e07877b285a838db11a           2017-09-29 00:00:00
# f6dd3ec061db4e3987629fe6b26e5cce           2017-05-15 00:00:00
# 6489ae5e4333f3693df5ad4372dab6d3           2018-02-05 00:00:00
# d4eb9395c8c0431ee92fce09860c5a06           2018-08-20 00:00:00
# 58dbd0b2d70206bf40e62cd34e84d795           2017-03-17 00:00:00
# ...                                                        ...
# b51593916b4b8e0d6f66f2ae24f2673d           2018-05-18 00:00:00
# 84c5d4fbaf120aae381fad077416eaa0           2018-08-01 00:00:00
# 29309aa813182aaddc9b259e31b870e6           2017-11-10 00:00:00
# b5e6afd5a41800fdf401e0272ca74655           2017-08-25 00:00:00
# 96d649da0cc4ff33bb408b199d4c7dcf           2018-06-28 00:00:00
#
# [102425 rows x 22 columns]

# %%
customer.head()
# Out:
#                                                 customer_unique_id  \
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#                                   customer_zip_code_prefix  \
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7                     14409
# 18955e83d337fd6b2def6b18a428ac77                      9790
# 4e7b3e00288586ebd08712fdd0374a03                      1151
# b2b6027bc5c5109e529d4dc6358b12c3                      8775
# 4f2d8ab171c80ec8364f7c12e35b23ad                     13056
#
#                                           customer_city customer_state
# customer_id
# 06b8999e2fba1a1fbc88172c00ba8bc7                 franca             SP
# 18955e83d337fd6b2def6b18a428ac77  sao bernardo do campo             SP
# 4e7b3e00288586ebd08712fdd0374a03              sao paulo             SP
# b2b6027bc5c5109e529d4dc6358b12c3        mogi das cruzes             SP
# 4f2d8ab171c80ec8364f7c12e35b23ad               campinas             SP

# %%
result1 = pd.merge(result1, customer,how='inner', on= 'customer_id').set_index('customer_id')
result1
# Out:
#                                                           order_id  \
# customer_id
# 3ce436f183e68e07877b285a838db11a  00010242fe8c5a6d1ba2dd792cb16214
# f6dd3ec061db4e3987629fe6b26e5cce  00018f77f2f0320c557190d7a144bdd3
# 6489ae5e4333f3693df5ad4372dab6d3  000229ec398224ef6ca0657da4fc703e
# d4eb9395c8c0431ee92fce09860c5a06  00024acbcdf0a6daa1e931b038114c75
# 58dbd0b2d70206bf40e62cd34e84d795  00042b26cf59d7ce69dfabb4e55b4fd9
# ...                                                            ...
# b51593916b4b8e0d6f66f2ae24f2673d  fffc94f6ce00a00581880bf54a75a037
# 84c5d4fbaf120aae381fad077416eaa0  fffcd46ef2263f404302a634eb57f7eb
# 29309aa813182aaddc9b259e31b870e6  fffce4705a9662cd70adb13d4a31832d
# b5e6afd5a41800fdf401e0272ca74655  fffe18544ffabc95dfada21779c9644f
# 96d649da0cc4ff33bb408b199d4c7dcf  fffe41c64501cc87c801fd61db3f6244
#
#                                                         product_id  \
# customer_id
# 3ce436f183e68e07877b285a838db11a
# 58dbd0b2d70206bf40e62cd34e84d795        varzea paulista             SP
# ...                                                 ...            ...
# b51593916b4b8e0d6f66f2ae24f2673d               sao luis             MA
# 84c5d4fbaf120aae381fad077416eaa0               curitiba             PR
# 29309aa813182aaddc9b259e31b870e6              sao paulo             SP
# b5e6afd5a41800fdf401e0272ca74655                vinhedo             SP
# 96d649da0cc4ff33bb408b199d4c7dcf               botucatu             SP
#
# [102425 rows x 34 columns]

# %%
# Out:
#                                 order_id                        product_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  4244733e06e7ecb4970a6e2683c13e61
# 1       00018f77f2f0320c557190d7a144bdd3  e5f2d52b802189ee658865ca93d83a8f
# 2       000229ec398224ef6ca0657da4fc703e  c777355d18b72b67abbeef9df44fd0fd
# 3       00024acbcdf0a6daa1e931b038114c75  7634da152a4610f1595efa32f14722fc
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  ac6c3623068f30de03045865e4e10089
# ...                                  ...                               ...
# 102420  fffc94f6ce00a00581880bf54a75a037  4aa6014eceb682077f9dc4bffebc05b0
# 102421  fffcd46ef2263f404302a634eb57f7eb  32e07fd915822b0765e448c4dd74c828
# 102422  fffce4705a9662cd70adb13d4a31832d  72a30483855e2eafc67aee5dc2560482
# 102423  fffe18544ffabc95dfada21779c9644f  9c422a519119dcad7575db5af1ba540e
# 102424  fffe41c64501cc87c801fd61db3f6244  350688d9dc1e75ff97be326363655e01
#
#                                seller_id   price  freight_value  \
# 0       48436dade18ac8b2bce089ec2a041202   58.90          13.29
# 1       dd7ddc04e1b6c2c614352b383efe2d36  239.90          19.93
# 2       5b51032eddd242adc84c38acab88f23d  199.00          17.87
# 3       9d7a1d34a5052409006425275ba1c2b4   12.99          12.79
# 4       df560393f3a51e74553ab94004ba5c87  199.90          18.14
# ...                                  ...     ...            ...
# 102420  b8bc237ba3788b23da09c0f1f3a3288c  299.99          43.41
# 102421  f3c38ab652836d21de61fb8314b69182  350.00          36.53
# 102422  c3cfdc648177fdbbbb35635a37472c53   99.90          16.95
# 102423  2b3e4a2a3ea8e01938cabda2a3e5cc79   55.99           8.72
# 102424  f7ccf836d21b2fb1de37564105216cc1   43.00          12.79
#
#         payment_sequential  payment_installments  payment_value  \
# 0                      1.0                   2.0          72.19
# 1                      1.0                   3.0         259.83
# 2                      1.0                   5.0         216.87
# 3                      1.0                   2.0          25.78
# 4                      1.0                   3.0         218.04
# ...                    ...                   ...            ...
# 102420                 1.0                   1.0         343.40
# 102421                 1.0                   1.0         386.53
# 102422                 1.0                   3.0         116.85
# 102423                 1.0                   3.0          64.71
# 102424                 1.0                   1.0          55.79
#
#          product_category_name  product_name_lenght  ...  \
# 0                   cool_stuff                 58.0  ...
# 1                     pet_shop                 56.0  ...
# 2             moveis_decoracao                 59.0  ...
# 3                   perfumaria                 42.0  ...
# 4           ferramentas_jardim                 59.0  ...
# ...                        ...                  ...  ...
# 102420   utilidades_domesticas                 43.0  ...
# 102421  informatica_acessorios                 31.0  ...
# 102422           esporte_lazer                 43.0  ...
# 102423  informatica_acessorios                 56.0  ...
# 102424         cama_mesa_banho                 47.0  ...
#
#         order_delivered_customer_date  order_estimated_delivery_date  \
# 0                 2017-09-20 23:43:48            2017-09-29 00:00:00
# 1                 2017-05-12 16:04:24            2017-05-15 00:00:00
# 2                 2018-01-22 13:19:16            2018-02-05 00:00:00
# 3                 2018-08-14 13:32:39            2018-08-20 00:00:00
# 4                 2017-03-01 16:42:31            2017-03-17 00:00:00
# ...                               ...                            ...
# 102420            2018-05-10 22:56:40            2018-05-18 00:00:00
# 102421            2018-07-23 20:31:55            2018-08-01 00:00:00
# 102422            2017-10-28 12:22:22            2017-11-10 00:00:00
# 102423            2017-08-16 21:59:40            2017-08-25 00:00:00
# 102424            2018-06-14 17:56:26            2018-06-28 00:00:00
#
#                     customer_unique_id_x  customer_zip_code_prefix_x  \
# 0       871766c5855e863f6eccc05f988b23cb                       28013
# 1       eb28e67c4c0b83846050ddfb8a35d051                       15775
# 2       3818d81c6709e39d06b2738a8d3a2474                       35661
# 3       af861d436cfc08b2c2ddefd0ba074622                       12952
# 4       64b576fb70d441e8f1b2d7d446e483c5                       13226
# ...                                  ...                         ...
# 102420  0c9aeda10a71f369396d0c04dce13a64                       65077
# 102421  0da9fe112eae0c74d3ba1fe16de0988b                       81690
# 102422  cd79b407828f02fdbba457111c38e4c4                        4039
# 102423  eb803377c9315b564bdedad672039306                       13289
# 102424  cd76a00d8e3ca5e6ab9ed9ecb6667ac4                       18605
#
#               customer_city_x  customer_state_x  \
# 0       campos dos goytacazes                RJ
# 1             santa fe do sul                SP
# 2               para de minas                MG
# 3                     atibaia                SP
# 4             varzea paulista                SP
# ...                       ...               ...
# 102420               sao luis                MA
# 102421               curitiba                PR
# 102422              sao paulo                SP
# 102423                vinhedo                SP
# 102424               botucatu                SP
#
#                     customer_unique_id_y customer_zip_code_prefix_y  \
# 0       871766c5855e863f6eccc05f988b23cb                      28013
# 1       eb28e67c4c0b83846050ddfb8a35d051                      15775
# 2       3818d81c6709e39d06b2738a8d3a2474                      35661
# 3       af861d436cfc08b2c2ddefd0ba074622                      12952
# 4       64b576fb70d441e8f1b2d7d446e483c5                      13226
# ...                                  ...                        ...
# 102420  0c9aeda10a71f369396d0c04dce13a64                      65077
# 102421  0da9fe112eae0c74d3ba1fe16de0988b                      81690
# 102422  cd79b407828f02fdbba457111c38e4c4                       4039
# 102423  eb803377c9315b564bdedad672039306                      13289
# 102424  cd76a00d8e3ca5e6ab9ed9ecb6667ac4                      18605
#
#               customer_city_y customer_state_y
# 0       campos dos goytacazes               RJ
# 1             santa fe do sul               SP
# 2               para de minas               MG
# 3                     atibaia               SP
# 4             varzea paulista               SP
# ...                       ...              ...
# 102420               sao luis               MA
# 102421               curitiba               PR
# 102422              sao paulo               SP
# 102423                vinhedo               SP
# 102424               botucatu               SP
#
# [102425 rows x 31 columns]

# %%
result1.columns
# Out:
# Index(['order_id', 'product_id', 'seller_id', 'price', 'freight_value',
#        'payment_sequential', 'payment_installments', 'payment_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'order_status', 'order_purchase_timestamp', 'order_approved_at',
#        'order_delivered_carrier_date', 'order_delivered_customer_date',
#        'order_estimated_delivery_date', 'customer_unique_id_x',
#        'customer_zip_code_prefix_x', 'customer_city_x', 'customer_state_x',
#        'customer_unique_id_y', 'customer_zip_code_prefix_y', 'customer_city_y',
#        'customer_state_y', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='object')

# %%
result1.drop(columns=['customer_unique_id_y', 'customer_zip_code_prefix_y', 'customer_city_y',
       'customer_state_y', 'customer_unique_id', 'customer_zip_code_prefix',
       'customer_city', 'customer_state'])
# Out:
#                                                           order_id  \
# customer_id
# 3ce436f183e68e07877b285a838db11a  00010242fe8c5a6d1ba2dd792cb16214
# f6dd3ec061db4e3987629fe6b26e5cce  00018f77f2f0320c557190d7a144bdd3
# 6489ae5e4333f3693df5ad4372dab6d3  000229ec398224ef6ca0657da4fc703e
# d4eb9395c8c0431ee92fce09860c5a06  00024acbcdf0a6daa1e931b038114c75
# 58dbd0b2d70206bf40e62cd34e84d795  00042b26cf59d7ce69dfabb4e55b4fd9
# ...                                                            ...
# b51593916b4b8e0d6f66f2ae24f2673d  fffc94f6ce00a00581880bf54a75a037
# 84c5d4fbaf120aae381fad077416eaa0  fffcd46ef2263f404302a634eb57f7eb
# 29309aa813182aaddc9b259e31b870e6  fffce4705a9662cd70adb13d4a31832d
# b5e6afd5a41800fdf401e0272ca74655  fffe18544ffabc95dfada21779c9644f
# 96d649da0cc4ff33bb408b199d4c7dcf  fffe41c64501cc87c801fd61db3f6244
#
#                                                         product_id  \
# customer_id
# 3ce436f183e68e07877b285a838db11a  4244733e06e7ecb4970a6e2683c13e61
# f6dd3ec061db4e3987629fe6b26e5cce  e5f2d52b802189ee658865ca93d83a8f
# 6489ae5e4333f3693df5ad4372dab6d3  c777355d18b72b67abbeef9df44fd0fd
# d4eb9395c8c0431ee92fce09860c5a06  7634da152a4610f1595efa32f14722fc
# 58dbd0b2d70206bf40e62cd34e84d795  ac6c3623068f30de03045865e4e10089
# ...                                                            ...
# b51593916b4b8e0d6f66f2ae24f2673d  4aa6014eceb682077f9dc4bffebc05b0
# 84c5d4fbaf120aae381fad077416eaa0  32e07fd915822b0765e448c4dd74c828
# 29309aa813182aaddc9b259e31b870e6  72a30483855e2eafc67aee5dc2560482
# b5e6afd5a41800fdf401e0272ca74655  9c422a519119dcad7575db5af1ba540e
# 96d649da0cc4ff33bb408b199d4c7dcf  350688d9dc1e75ff97be326363655e01
#
#                                                          seller_id   price  \
# customer_id
# 3ce436f183e68e07877b285a838db11a  48436dade18ac8b2bce089ec2a041202   58.90
# f6dd3ec061db4e3987629fe6b26e5cce  dd7ddc04e1b6c2c614352b383efe2d36  239.90
# 6489ae5e4333f3693df5ad4372dab6d3  5b51032eddd242adc84c38acab88f23d  199.00
# d4eb9395c8c0431ee92fce09860c5a06  9d7a1d34a5052409006425275ba1c2b4   12.99
# 58dbd0b2d70206bf40e62cd34e84d795  df560393f3a51e74553ab94004ba5c87  199.90
# ...                                                            ...     ...
# b51593916b4b8e0d6f66f2ae24f2673d  b8bc237ba3788b23da09c0f1f3a3288c  299.99
# 84c5d4fbaf120aae381fad077416eaa0  f3c38ab652836d21de61fb8314b69182  350.00
# 29309aa813182aaddc9b259e31b870e6  c3cfdc648177fdbbbb35635a37472c53   99.90
# b5e6afd5a41800fdf401e0272ca74655  2b3e4a2a3ea8e01938cabda2a3e5cc79   55.99
# 96d649da0cc4ff33bb408b199d4c7dcf  f7ccf836d21b2fb1de37564105216cc1   43.00
#
#                                   freight_value  payment_sequential  \
# customer_id
# 3ce436f183e68e07877b285a838db11a          13.29                 1.0
# f6dd3ec061db4e3987629fe6b26e5cce          19.93                 1.0
# 6489ae5e4333f3693df5ad4372dab6d3          17.87                 1.0
# d4eb9395c8c0431ee92fce09860c5a06          12.79                 1.0
# 58dbd0b2d70206bf40e62cd34e84d795          18.14                 1.0
# ...                                         ...                 ...
# b51593916b4b8e0d6f66f2ae24f2673d          43.41                 1.0
# 84c5d4fbaf120aae381fad077416eaa0          36.53                 1.0
# 29309aa813182aaddc9b259e31b870e6          16.95                 1.0
# b5e6afd5a41800fdf401e0272ca74655           8.72                 1.0
# 96d649da0cc4ff33bb408b199d4c7dcf          12.79                 1.0
#
#                                   payment_installments  payment_value  \
# customer_id
# 3ce436f183e68e07877b285a838db11a                   2.0          72.19
# f6dd3ec061db4e3987629fe6b26e5cce                   3.0         259.83
# 6489ae5e4333f3693df5ad4372dab6d3                   5.0         216.87
# d4eb9395c8c0431ee92fce09860c5a06                   2.0          25.78
# 58dbd0b2d70206bf40e62cd34e84d795                   3.0         218.04
# ...                                                ...            ...
# b51593916b4b8e0d6f66f2ae24f2673d                   1.0         343.40
# 84c5d4fbaf120aae381fad077416eaa0                   1.0         386.53
# 29309aa813182aaddc9b259e31b870e6                   3.0         116.85
# b5e6afd5a41800fdf401e0272ca74655                   3.0          64.71
# 96d649da0cc4ff33bb408b199d4c7dcf                   1.0          55.79
#
#                                    product_category_name  product_name_lenght  \
# customer_id
# 3ce436f183e68e07877b285a838db11a              cool_stuff                 58.0
# f6dd3ec061db4e3987629fe6b26e5cce                pet_shop                 56.0
# 6489ae5e4333f3693df5ad4372dab6d3        moveis_decoracao                 59.0
# d4eb9395c8c0431ee92fce09860c5a06              perfumaria                 42.0
# 58dbd0b2d70206bf40e62cd34e84d795      ferramentas_jardim                 59.0
# ...                                                  ...                  ...
# b51593916b4b8e0d6f66f2ae24f2673d   utilidades_domesticas                 43.0
# 84c5d4fbaf120aae381fad077416eaa0  informatica_acessorios                 31.0
# 29309aa813182aaddc9b259e31b870e6           esporte_lazer                 43.0
# b5e6afd5a41800fdf401e0272ca74655  informatica_acessorios                 56.0
# 96d649da0cc4ff33bb408b199d4c7dcf         cama_mesa_banho                 47.0
#
#                                   ...  order_status  order_purchase_timestamp  \
# customer_id                       ...
# 3ce436f183e68e07877b285a838db11a  ...     delivered       2017-09-13 08:59:02
# f6dd3ec061db4e3987629fe6b26e5cce  ...     delivered       2017-04-26 10:53:06
# 6489ae5e4333f3693df5ad4372dab6d3  ...     delivered       2018-01-14 14:33:31
# d4eb9395c8c0431ee92fce09860c5a06  ...     delivered       2018-08-08 10:00:35
# 58dbd0b2d70206bf40e62cd34e84d795  ...     delivered       2017-02-04 13:57:51
# ...                               ...           ...                       ...
# b51593916b4b8e0d6f66f2ae24f2673d  ...     delivered       2018-04-23 13:57:06
# 84c5d4fbaf120aae381fad077416eaa0  ...     delivered       2018-07-14 10:26:46
# 29309aa813182aaddc9b259e31b870e6  ...     delivered       2017-10-23 17:07:56
# b5e6afd5a41800fdf401e0272ca74655  ...     delivered       2017-08-14 23:02:59
# 96d649da0cc4ff33bb408b199d4c7dcf  ...     delivered       2018-06-09 17:00:18
#
#                                     order_approved_at  \
# customer_id
# 3ce436f183e68e07877b285a838db11a
# 29309aa813182aaddc9b259e31b870e6            2017-11-10 00:00:00
# b5e6afd5a41800fdf401e0272ca74655            2017-08-25 00:00:00
# 96d649da0cc4ff33bb408b199d4c7dcf            2018-06-28 00:00:00
#
#                                               customer_unique_id_x  \
# customer_id
# 3ce436f183e68e07877b285a838db11a  871766c5855e863f6eccc05f988b23cb
# f6dd3ec061db4e3987629fe6b26e5cce  eb28e67c4c0b83846050ddfb8a35d051
# 6489ae5e4333f3693df5ad4372dab6d3  3818d81c6709e39d06b2738a8d3a2474
# d4eb9395c8c0431ee92fce09860c5a06  af861d436cfc08b2c2ddefd0ba074622
# 58dbd0b2d70206bf40e62cd34e84d795  64b576fb70d441e8f1b2d7d446e483c5
# ...                                                            ...
# b51593916b4b8e0d6f66f2ae24f2673d  0c9aeda10a71f369396d0c04dce13a64
# 84c5d4fbaf120aae381fad077416eaa0  0da9fe112eae0c74d3ba1fe16de0988b
# 29309aa813182aaddc9b259e31b870e6  cd79b407828f02fdbba457111c38e4c4
# b5e6afd5a41800fdf401e0272ca74655  eb803377c9315b564bdedad672039306
# 96d649da0cc4ff33bb408b199d4c7dcf  cd76a00d8e3ca5e6ab9ed9ecb6667ac4
#
#                                  customer_zip_code_prefix_x  \
# customer_id
# 3ce436f183e68e07877b285a838db11a                      28013
# f6dd3ec061db4e3987629fe6b26e5cce                      15775
# 6489ae5e4333f3693df5ad4372dab6d3                      35661
# d4eb9395c8c0431ee92fce09860c5a06                      12952
# 58dbd0b2d70206bf40e62cd34e84d795                      13226
# ...                                                     ...
# b51593916b4b8e0d6f66f2ae24f2673d                      65077
# 84c5d4fbaf120aae381fad077416eaa0                      81690
# 29309aa813182aaddc9b259e31b870e6                       4039
# b5e6afd5a41800fdf401e0272ca74655                      13289
# 96d649da0cc4ff33bb408b199d4c7dcf                      18605
#
#                                         customer_city_x customer_state_x
# customer_id
# 3ce436f183e68e07877b285a838db11a  campos dos goytacazes               RJ
# f6dd3ec061db4e3987629fe6b26e5cce        santa fe do sul               SP
# 6489ae5e4333f3693df5ad4372dab6d3          para de minas               MG
# d4eb9395c8c0431ee92fce09860c5a06                atibaia               SP
# 58dbd0b2d70206bf40e62cd34e84d795        varzea paulista               SP
# ...                                                 ...              ...
# b51593916b4b8e0d6f66f2ae24f2673d               sao luis               MA
# 84c5d4fbaf120aae381fad077416eaa0               curitiba               PR
# 29309aa813182aaddc9b259e31b870e6              sao paulo               SP
# b5e6afd5a41800fdf401e0272ca74655                vinhedo               SP
# 96d649da0cc4ff33bb408b199d4c7dcf               botucatu               SP
#
# [102425 rows x 26 columns]

# %%
counts = result1[('customer_unique_id')].value_counts()
count=result1.drop_duplicates()
counts
# Out:
# 8d50f5eadf50201ccdcedfb9e2ac8455    16
# 3e43e6105506432c953e165fb2acf44c    13
# 1b6c7548a2a1f9037c1fd3ddfed95f33     9
# ca77025e7201e3b30c44b472ff346268     9
# 6469f99c1f9dfae7733b25662e7f1782     8
#                                     ..
# 0f0ca903ef374e6e561ebbecbddc28c2     1
# 0f421aad1e168dac3f1a246e4627ab9c     1
# 72c4723cc696a1935b38ed1e0c7b5ec5     1
# 41678bd77f241a2270d0a5d905b22020     1
# 214a6059c941ccf392c784770d0d566d     1
# Name: customer_unique_id, Length: 95420, dtype: int64

# %%
fig = plt.figure(figsize=(10,10)) # define plot area
ax = fig.gca() # define axis    
counts.plot.bar(ax = ax) # Use the plot.bar method on the counts data frame
ax.set_title('Number of products by type') # Give the plot a main title
ax.set_xlabel('Product_category_name') # Set text for the x axis
ax.set_ylabel('Number of items')# Set text for y axis
# Out:
# Text(0, 0.5, 'Number of items')

# %%
result1.columns
# Out:
# Index(['order_id', 'product_id', 'seller_id', 'price', 'freight_value',
#        'payment_sequential', 'payment_installments', 'payment_value',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
result1['order_purchase_timestamp'] = pd.to_datetime(result1['order_purchase_timestamp'])
result1['order_date'] = result1.order_purchase_timestamp.dt.date
result1['order_delivered_customer_date'] = pd.to_datetime(result1['order_delivered_customer_date'])
result1['order_estimated_delivery_date'] = pd.to_datetime(result1['order_estimated_delivery_date'])
result1['order_approved_at'] = pd.to_datetime(result1['order_approved_at'])

# %%
result1['order_purchase_timestamp'].describe
# Out:
# <bound method NDFrame.describe of 0        2017-09-13 08:59:02
# 1        2017-04-26 10:53:06
# 2        2018-01-14 14:33:31
# 3        2018-08-08 10:00:35
# 4        2017-02-04 13:57:51
#                  ...
# 102420   2018-04-23 13:57:06
# 102421   2018-07-14 10:26:46
# 102422   2017-10-23 17:07:56
# 102423   2017-08-14 23:02:59
# 102424   2018-06-09 17:00:18
# Name: order_purchase_timestamp, Length: 102425, dtype: datetime64[ns]>

# %%
result1['customer_unique_id'].describe
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'customer_unique_id'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-37-17de3e8dadb3> in <module>
# ----> 1 result1['customer_unique_id'].describe
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2978             if self.columns.nlevels > 1:
#    2979                 return self._getitem_multilevel(key)
# -> 2980             indexer = self.columns.get_loc(key)
#    2981             if is_integer(indexer):
#    2982                 indexer = [indexer]
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'customer_unique_id'

# %%
DatetimeIndex(['2018-01-01 00:00:00', '2018-01-01 01:00:00',
               '2018-01-01 02:00:00', '2018-01-01 03:00:00',
               '2018-01-01 04:00:00', '2018-01-01 05:00:00',
               '2018-01-01 06:00:00', '2018-01-01 07:00:00',
               '2018-01-01 08:00:00', '2018-01-01 09:00:00',
               ...
               '2018-01-07 15:00:00', '2018-01-07 16:00:00',
               '2018-01-07 17:00:00', '2018-01-07 18:00:00',
               '2018-01-07 19:00:00', '2018-01-07 20:00:00',
               '2018-01-07 21:00:00', '2018-01-07 22:00:00',
               '2018-01-07 23:00:00', '2018-01-08 00:00:00'],
              dtype='datetime64[ns]', length=169, freq='H')

# %%
result1['order_date'] = pd.order_purchase_timestamp.dt.date
result1['order_date'] = pd.to_datetime(result1['order_date'])

#cols = ['customer_unique_id', 'order_date']
#elog = elog[cols]

#elog.columns = ['CUSTOMER_ID', 'ORDER_DATE']


#result1.info()
display(result1.sample(5))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-32528e962668> in <module>
# ----> 1 result1['order_date'] = pd.order_purchase_timestamp.dt.date
#       2 result1['order_date'] = pd.to_datetime(result1['order_date'])
#       3
#       4 #cols = ['customer_unique_id', 'order_date']
#       5 #elog = elog[cols]
#
# ~/miniconda3/lib/python3.7/site-packages/pandas/__init__.py in __getattr__(name)
#     212
#     213             return Panel
# --> 214         raise AttributeError("module 'pandas' has no attribute '{}'".format(name))
#     215
#     216
#
# AttributeError: module 'pandas' has no attribute 'order_purchase_timestamp'
